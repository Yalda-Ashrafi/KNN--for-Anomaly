# %% [markdown]
# <a href="https://colab.research.google.com/github/Yalda-Ashrafi/KNN--for-Anomaly/blob/main/KNN_for_Anomaly.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import NearestNeighbors

# %%
df=pd.read_csv("iris.csv")
df=df[['sepal length','sepal width']]

# %%
df=pd.read_csv("iris.csv")
df=df[['sepal length','sepal width']]

# %%
plt.scatter(df['sepal length'], df['sepal width'])

# %%
x=df.values
nbrs=NearestNeighbors(n_neighbors=3)
nbrs.fit(x)
# Out:
# NearestNeighbors(n_neighbors=3)

# %%
distance, indexes=nbrs.kneighbors(x)
plt.plot(distance.mean(axis=1))

# %%
outlier_index=np.where(distance.mean(axis=1)>0.15)
outlier_index
# Out:
# (array([], dtype=int64),)

# %%
outlier_values=df.iloc[outlier_index]
outlier_values
# Out:
# Empty DataFrame
# Columns: [sepal length, sepal width]
# Index: []

# %%
print(distance.mean(axis=1).min())
print(distance.mean(axis=1).max())
# Out:
# 0.0
# 0.1490711984999861

# %%
outlier_index = np.where(distance.mean(axis=1) > 0.15)

# %%
df.iloc[outlier_index]
# Out:
# Empty DataFrame
# Columns: [sepal length, sepal width]
# Index: []

# %%
distance.mean(axis=1)
# Out:
# array([0.        , 0.03333333, 0.        , ..., 0.        , 0.        ,
#        0.        ])

# %%
outlier_index = np.where(distance.mean(axis=1) > 0.05)

# %%
means = distance.mean(axis=1)
print(sorted(means)[-10:])  # see top values
# Out:
# [np.float64(0.06666666666666703), np.float64(0.06666666666666703), np.float64(0.06666666666666703), np.float64(0.0745355992499928), np.float64(0.0745355992499928), np.float64(0.08047378541243647), np.float64(0.08047378541243662), np.float64(0.10786893258332635), np.float64(0.11380711874576983), np.float64(0.1490711984999861)]

# %%
outlier_values=df.iloc[outlier_index]
outlier_values
# Out:
#       sepal length  sepal width
# 68             4.3          3.0
# 184            5.6          4.3
# 239            4.8          3.2
# 274            4.8          2.9
# 314            5.5          4.1
# 447            4.4          2.6
# 511            5.8          3.9
# 651            4.7          2.8
# 667            4.6          3.6
# 818            4.5          2.4
# 819            4.5          2.3
# 825            4.4          2.6
# 906            4.7          3.6
# 1005           5.4          2.3
# 1214           5.6          2.3
# 1314           5.9          2.7
# 1325           6.7          2.8
# 1511           6.0          2.4
# 1542           6.1          3.4
# 1630           5.9          2.2
# 1708           6.8          2.9
# 1749           5.8          3.2
# 1930           5.8          3.1
# 1995           5.2          2.7
# 2094           6.1          2.7
# 2132           7.7          3.7
# 2158           6.2          3.1
# 2170           6.4          3.3
# ...

# %%
plt.scatter(df['sepal length'],df['sepal width'], color='b',s=65)
plt.scatter(outlier_values['sepal length'],outlier_values['sepal width'],color='r')
